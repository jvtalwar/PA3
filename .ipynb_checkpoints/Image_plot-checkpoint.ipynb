# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np


from torchvision import utils
from basic_fcn import *
from dataloader2 import *
from utils import *
import torchvision
import torch.nn.functional as F
import torch.optim as optim
from torch.autograd import Variable
import time

# %%
def data2img(torch_img):
    img = torch_img.permute(1, 2, 0).numpy()
    for i in range(3):
        img[:, :, i] -= np.min(img[:, :, i])
        img[:, :, i] /= np.max(img[:, :, i])
    return img

# %%
def plot_image_label(img, lbl):
    fig, ax = plt.subplots(ncols = 2, figsize = (20, 10))
    ax[0].imshow(img)
    ax[1].imshow(lbl)
    plt.tight_layout()

# %%
n_class = 34
dataset = CityScapesDataset(csv_file='train.csv')

init_sample = dataset.__getitem__(11)
init_img = data2img(init_sample[0])
init_lbl = init_sample[2].numpy()
plot_image_label(init_img, init_lbl)

# %%
dataset_aug = CityScapesDataset(csv_file='train.csv', transforms = None, resize_factor=0.5)

trans_sample = dataset_aug.__getitem__(11)
trans_img = data2img(trans_sample[0])
trans_lbl = trans_sample[2].numpy()
plot_image_label(trans_img, trans_lbl)

# %%
trans_img.mean(axis = (0, 1))
# Out:
# array([0.17459148, 0.22033553, 0.18966004], dtype=float32)

# %%
init_img.mean(axis = (0, 1))
# Out:
# array([0.2129038 , 0.2229821 , 0.21772395], dtype=float32)

# %%
plt.imshow(init_lbl, vmax = n_class)

plt.tight_layout()

# %%
from matplotlib.cm import get_cmap

cmap = get_cmap('viridis')

# %%
a = list(map(lambda x: cmap((x / n_class * cmap.N).astype(int)), init_lbl))

# %%
plt.imshow(np.array(a), alpha = 0.7)
plt.imshow(init_img, alpha = 0.3)

# %%
def image_overlay(img, label, saving_dir, alpha = 0.5):
    from matplotlib.cm import get_cmap
    cmap = get_cmap('viridis')
    
    # converts labels to some colour
    a = list(map(lambda x: cmap((x / n_class * cmap.N).astype(int)), init_lbl))
    
    plt.imshow(np.array(a), alpha = 0.7)
    
    plt.imshow(init_img, alpha = 0.3)
    plt.imsave(saving_dir)
# Out:
# [[0.271305 0.019942 0.347269 1.      ]
#  [0.271305 0.019942 0.347269 1.      ]
#  [0.271305 0.019942 0.347269 1.      ]
#  ...
#  [0.271305 0.019942 0.347269 1.      ]
#  [0.271305 0.019942 0.347269 1.      ]
#  [0.271305 0.019942 0.347269 1.      ]]
# [[0.271305 0.019942 0.347269 1.      ]
#  [0.271305 0.019942 0.347269 1.      ]
#  [0.271305 0.019942 0.347269 1.      ]
#  ...
#  [0.271305 0.019942 0.347269 1.      ]
#  [0.271305 0.019942 0.347269 1.      ]
#  [0.271305 0.019942 0.347269 1.      ]]
# [[0.271305 0.019942 0.347269 1.      ]
#  [0.271305 0.019942 0.347269 1.      ]
#  [0.271305 0.019942 0.347269 1.      ]
#  ...
#  [0.271305 0.019942 0.347269 1.      ]
#  [0.271305 0.019942 0.347269 1.      ]
#  [0.271305 0.019942 0.347269 1.      ]]
# [[0.271305 0.019942 0.347269 1.      ]
#  [0.271305 0.019942 0.347269 1.      ]
#  [0.271305 0.019942 0.347269 1.      ]
#  ...
#  [0.271305 0.019942 0.347269 1.      ]
#  [0.271305 0.019942 0.347269 1.      ]
# ...

# %%
init_lbl.numpy()
# Out:
# array([[3, 3, 3, ..., 3, 3, 3],
#        [3, 3, 3, ..., 3, 3, 3],
#        [3, 3, 3, ..., 3, 3, 3],
#        ...,
#        [3, 3, 3, ..., 3, 3, 3],
#        [3, 3, 3, ..., 3, 3, 3],
#        [3, 3, 3, ..., 3, 3, 3]])

# %%
(10 * np.random.rand(10, 2)).astype(int)
# Out:
# array([[0, 1],
#        [0, 5],
#        [1, 1],
#        [2, 5],
#        [9, 2],
#        [8, 0],
#        [5, 9],
#        [2, 0],
#        [4, 1],
#        [3, 1]])
